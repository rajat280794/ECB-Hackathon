# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('COICOP.csv')

# %%
df.head(10)
# Out:
#      Order  Level  Code  Parent           Code.1 Parent.1  \
# 0  1824814      1    10     NaN            TOTAL      NaN
# 1  1824815      1    20     NaN  TOT_X_CP041_042      NaN
# 2  1824816      1    30     NaN             CP00      NaN
# 3  1824817      1    40     NaN             CP01      NaN
# 4  1824818      2    50    40.0            CP011     CP01
# 5  1824819      3    60    50.0           CP0111    CP011
# 6  1824820      4    70    60.0          CP01111   CP0111
# 7  1824821      5    80    70.0         CP01111A  CP01111
# 8  1824822      4    90    60.0          CP01112   CP0111
# 9  1824823      5   100    90.0         CP01112A  CP01112
#
#                         Description  Remark
# 0                             Total     NaN
# 1         Total except actual rents     NaN
# 2                    All-items HICP     NaN
# 3  Food and non-alcoholic beverages     NaN
# 4                              Food     NaN
# 5                 Bread and cereals     NaN
# ...

# %%
df_2 = pd.read_csv('hierarchial_level.csv')

# %%
df_2.head(50)
# Out:
#       Order  Level  Code  Parent               Code.1  Parent.1  \
# 0   1824814      1    10     NaN                TOTAL       NaN
# 1   1824815      1    20     NaN      TOT_X_CP041_042       NaN
# 2   1824816      1    30     NaN                 CP00       NaN
# 3   1824817      1    40     NaN                 CP01       NaN
# 4   1824966      1  1530     NaN                 CP02       NaN
# 5   1824994      1  1810     NaN                 CP03       NaN
# 6   1825047      1  2340     NaN                 CP04       NaN
# 7   1825097      1  2840     NaN                 CP05       NaN
# 8   1825204      1  3910     NaN                 CP06       NaN
# 9   1825255      1  4420     NaN                 CP07       NaN
# 10  1825312      1  4990     NaN                 CP08       NaN
# 11  1825332      1  5190     NaN                 CP09       NaN
# 12  1825450      1  6370     NaN                 CP10       NaN
# 13  1825469      1  6560     NaN                 CP11       NaN
# ...
